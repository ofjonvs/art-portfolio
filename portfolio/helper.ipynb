# %%
import os
import django

os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'portfolio.settings')
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"
django.setup()

from django.contrib.auth.models import User

# %%
# filepath: vscode-notebook-cell:/Users/jonas/python-workspace/website/soph_art/portfolio/helper.ipynb#W2sZmlsZQ%3D%3D
from main.models import *

Artwork.objects.all()
# Out:
# <QuerySet [<Artwork: Demise’s Sanctuary>]>
