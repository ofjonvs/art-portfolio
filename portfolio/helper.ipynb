# %%
import os
import django

os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'portfolio.settings')
django.setup()

from django.contrib.auth.models import User

# %%
user = User.objects.create_user(username='newuser', password='securepassword')
# Out:
# ---------------------------------------------------------------------------
# SynchronousOnlyOperation                  Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 user = User.objects.create_user(username='newuser', password='securepassword')
#
# File ~/python-workspace/website/soph_art/venv/lib/python3.8/site-packages/django/contrib/auth/models.py:161, in UserManager.create_user(self, username, email, password, **extra_fields)
#     159 extra_fields.setdefault("is_staff", False)
#     160 extra_fields.setdefault("is_superuser", False)
# --> 161 return self._create_user(username, email, password, **extra_fields)
#
# File ~/python-workspace/website/soph_art/venv/lib/python3.8/site-packages/django/contrib/auth/models.py:155, in UserManager._create_user(self, username, email, password, **extra_fields)
#     153 user = self.model(username=username, email=email, **extra_fields)
#     154 user.password = make_password(password)
# --> 155 user.save(using=self._db)
# ...
